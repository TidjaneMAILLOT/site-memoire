# %% [markdown]
# # Mémoire de Tidjane

# %% [markdown]
# ## 1/ Récursivité

# %% [markdown]
# ## 2/ Graphes

# %% [markdown]
# ...

# %% [markdown]
# ## 3/ Arbres

# %% [markdown]
# ...

# %% [markdown]
# ## 1/ Récursivité

# %% [markdown]
# ...

# %% [markdown]
# ## 1/ Récursivité

# %% [markdown]
# ...

# %% [markdown]
# # 6/ Les Bases

# %% [markdown]
# Puissances de 2 :
# 2⁰ = 1
# 2¹ = 2
# 2² = 4
# 2³ = 8
# 2⁴ = 16
# 2⁵ = 32
# 2⁶ = 64
# 2⁷ = 128
# 2⁸ = 256
#
# Binaire : base 2 → 0 et 1
# Décimal : base 10 → 0 à 9
# Hexadécimal : base 16 → 0 à 9 + A à F
#
# 1011₂ = 8 + 2 + 1 = 11₁₀
#
# 11₁₀ = 1011₂
#
# 1 chiffre hexadécimal = 4 bits
# F = 1111
# 2F = 0010 1111
#
# Complément à 2 :
# si c'est 1= négatif donc on convertit en trouvant le nombre positif et en lui enlevant 256
# si cest positif on trouve le nombre et on lui ajoute 256
#
# MSB = bit à gauche
# LSB = bit à droite
#
# ASCII = 7 bits = 128 valeurs
# Latin-1 = 8 bits = 256 valeurs
# UTF-8 = 1 à 4 octets
#
# bin(11) → 0b1011
# hex(47) → 0x2f
# ord("A") → 65
# chr(65) → A

# %% [markdown]
# ## 1/ Récursivité

# %% [markdown]
# ...
